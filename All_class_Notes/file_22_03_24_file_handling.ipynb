# %%
#file_handling

# %%
file_obj=open('/content/Sample',mode='r')

# %%
print(file_obj)
# Out:
# <_io.TextIOWrapper name='/content/Sample' mode='r' encoding='UTF-8'>

# %%
file_obj.read()
# Out:
# 'Hello, Ahmad '

# %%
file_obj=open('/content/Sample',mode='r')
file_obj.readlines()
# Out:
# ['Hello, Ahmad ']

# %%
#mode = 'w'
#writing purpose
file_obj=open('/content/Sample',mode='w')
file_obj.write('This is a Business Analyst Class')
file_obj.close()

# %%
file_obj=open('/content/Sample',mode='r')
file_obj.readlines()
# Out:
# ['This is a Business Analyst Class']

# %%
file_obj=open('/content/Sample',mode='r')
file_obj.readline()
# Out:
# 'This is a Business Analyst Class'

# %%
#append mode
file_obj=open('/content/sample',mode='a')
file_obj.write(" Welcome to the class")
file_obj.close()

# %%
file_obj=open('/content/sample',mode='r')
file_obj.readlines()
# Out:
# [' Welcome to the class Welcome to the class']

# %%
obj = open('/content/terrorismData.csv',mode='r')

# %%
final_data = obj.readlines()

# %%
type(final_data)
# Out:
# list

# %%
for i in range(0,len(final_data)):
  print(final_data[i][15:22])
# Out:
# t of Gr
#
#  Brigad
# ansur B
# ization
# alists,
# ,1
#
#  (AFA),
# a Army,
# ,1
#
# q,632
#
# h Batta
#  Counci
#
# 28
#
# 1
#
# 17
#
#  wal Su
# rkers P
# Baath P
#  of a S
# aqq,67
#
# ists,3
#
#
#
# ,1
#
# las,1
#
# n Hassa
# aq),1
#
# n Counc
#
# 1
#
# ba,1
#
# 1
#
# Black B
# igade,2
# s,6
#
# anguard
# n,2
#
# Congres
# nary Fo
# remists
#  League
#  Iraq (
# es,1
#
# rigades
# t of Ir
# in,2
#
# on Fron
# f Iraq
# f Iraq
# ists,1
#
#  al-Man
# d (Iraq
# rs,1
#
#  Battal
#  Group,
#
#
#  Brigad
#  Ali,1
#
# ah,7
#
# d Briga
# tic Par
# ts,2
#
# ga Guer
# nal Uni
# rs' Par
#
# ilee,1
#
#
# ar Grou
#
# l of th
# ,3
#
# ades,1
#
# s in Ir
# p,1
#
# a Counc
# lq (MEK
#
# lyi Bri
# ts,32
#
#  Moveme
# b Group
#  of Kur
# ation F
# extremi
# slam Br
# ,1
#
#  al-Sid
#
# remists
#  Brigad
# tremist
# s,1
#
#  for Ji
#  for Is
# a (Exco
# d,49
#
# he Whit
#
#  Social
#
# 36

# %%
for i in range(0,len(final_data)):
  print(final_data[i][0:4])
# Out:
# Row
# Iraq
# 1920
# Abu
# Abu
# Al Z
# Al-D
# Al-F
# Al-N
# Al-N
# Al-Q
# Al-Q
# Anba
# Ansa
# Ansa
# Ansa
# Ansa
# Ansa
# Anti
# Arab
# Arme
# Asa'
# Baat
# Badr
# Bann
# Barz
# Brig
# Deat
# Diya
# Gunm
# Hama
# Hara
# Hizb
# Hold
# Imam
# Iraq
# Iraq
# Iraq
# Iraq
# Iraq
# Iraq
# Iraq
# Isla
# Isla
# Isla
# Isla
# Isla
# Isla
# Isla
# Isla
# Isla
# Jais
# Jais
# Jiha
# Juna
# Jund
# Jund
# Just
# Kata
# Kata
# Khal
# Kurd
# Kurd
# Kurd
# Kurd
# Kurd
# Kurd
# Libe
# Mahd
# Mart
# Mili
# Mili
# Muja
# Muja
# Muja
# Muja
# Muja
# Muja
# Mukh
# Muna
# Musl
# Nati
# Omar
# Patr
# Popu
# Pro-
# Prot
# Reve
# Sala
# Sepa
# Shia
# Shie
# Sunn
# Sunn
# Supr
# Supr
# Takf
# Tawh
# The
# Trib
# Unif
# Unkn
# Gran

# %%
import csv

# %%
file_obj = open('/content/terrorismData.csv',mode='r')
file_data = csv.reader(file_obj)

final_data = list(file_data)

for i in final_data[0:100]:
  print(i)
# Out:
# ['Row Labels', 'Count of Group']
# ['Iraq', '24636']
# ['1920 Revolution Brigades', '2']
# ['Abu Jaafar al-Mansur Brigades', '1']
# ['Abu Nidal Organization (ANO)', '1']
# ['Al Zawahiri Loyalists', '1']
# ["Al-Da'wah Party", '1']
# ['Al-Fatihin Army (AFA)', '1']
# ['Al-Naqshabandiya Army', '35']
# ['Al-Nusrah Front', '1']
# ['Al-Qaida in Iraq', '632']
# ['Al-Qaida Kurdish Battalions (AQKB)', '2']
# ['Anbar Salvation Council', '1']
# ['Ansar al-Din', '1']
# ['Ansar al-Islam', '28']
# ['Ansar al-Jihad', '1']
# ['Ansar al-Sunna', '17']
# ['Ansar al-Tahwid wal Sunna', '1']
# ['Anti Kurdish Workers Party Iraq nationals', '1']
# ['Arab Socialist Baath Party of Iraq', '1']
# ['Armed Vanguards of a Second Mohammed Army', '1']
# ["Asa'ib Ahl al-Haqq", '67']
# ['Baathist extremists', '3']
# ['Badr Brigades', '3']
# ['Banner of Islam', '1']
# ['Barzani Guerrillas', '1']
# ['Brigades of Iman Hassan-al-Basri', '1']
# ['Death Squad (Iraq)', '1']
# ['Diyala Salvation Council', '1']
# ...

# %%
file_obj = open('/content/terrorismData.csv',mode='r')
file_data = csv.DictReader(file_obj)

final_data = list(file_data)

'''for i in final_data:
  print(i['City'])'''
# Out:
# "for i in final_data:\n  print(i['City'])"

# %%
d = {101:'Prabhjot',102:'Kishan'}

# %%
d[102]
# Out:
# 'Kishan'
